# %% [markdown]
# environment: conda activate flightops

# %%
import pandas as pd
import glob

files = glob.glob('data/raw/*.csv')

dfs = [pd.read_csv(file, low_memory=False) for file in files]
flights = pd.concat(dfs, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 7
#       4 files = glob.glob('data/raw/*.csv')
#       6 dfs = [pd.read_csv(file, low_memory=False) for file in files]
# ----> 7 flights = pd.concat(dfs, ignore_index=True)
#
# File /opt/anaconda3/envs/flightops/lib/python3.11/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...
