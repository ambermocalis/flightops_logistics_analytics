# %% [markdown]
# environment: conda activate datasci311

# %%
import pandas as pd
import glob

files = glob.glob('data/raw/csv/*.csv')

dfs = [pd.read_csv(file, low_memory=False) for file in files]
#flights = pd.concat(dfs, ignore_index=True)
print(files)
# Out:
# []
